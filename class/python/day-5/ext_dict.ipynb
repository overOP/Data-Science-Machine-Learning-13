# %%
data = {
    "name": "pradeep",
    "age": 24
}
data1 = {
    "callable": True,
    "number": [
        9812733452,
        9812733453
    ]
}

# %%
full_data = {**data, **data1}
print(full_data)
# Out:
# {'name': 'pradeep', 'age': 24, 'callable': True, 'number': [9812733452, 9812733453]}

# %%
full_data1 = data | data1
print(full_data1)
# Out:
# {'name': 'pradeep', 'age': 24, 'callable': True, 'number': [9812733452, 9812733453]}

# %%
update_one = {
    "age": 24
}
x = update_one["age"] = 25

# %%
print(update_one)
print(x)
# Out:
# {'age': 25}
# 25
