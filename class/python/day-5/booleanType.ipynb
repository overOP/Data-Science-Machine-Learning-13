# %%
flag = True
type(flag)
# Out:
# bool

# %%
c = 5 > 6
print(c)
# Out:
# False

# %% [markdown]
# and : returns True if both operands are True, otherwise False
# or : return True if either operand is True, othrtwise False
# not : negates the value of the operand

# %%
5 > 6 and 5 > 10
# Out:
# False

# %%
5 <= 6 or 5 > 10
# Out:
# True

# %%
not 5 > 6
# Out:
# True

# %%
bool("a")
# Out:
# True
