# %% [markdown]
# # Python OS Module
#
# The `os` module in Python provides a way of interacting with the operating system.
#
# It provides a way to access and manipulate files and directories, start and stop processes, get information about the system, and more.
#
# ## Working with Files and Directories
#
# Let's explore the `os` module and its various functions and methods that support working with files and directories.
#
# - `os.getcwd()`: Get the current working directory.
# - `os.mkdir('path')`: Create a new directory.
# - `os.chdir('path')`: Change the current working directory.
# - `os.listdir('path')`: List the contents of a directory.
# - `os.rename('old_name', 'new_name')`: Rename a file or a directory.
# - `os.remove('file_to_delete')`: Remove a file.
# - `os.rmdir('directory_to_delete')`: Remove a directory.
# - `os.path.dirname('path')`: Returns the name of the directory containing pathname path.
# - `os.path.exists('path')`: Checks if the path already exists; if so, returns `True`.

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/over/Documents/Code/Data Science & Machine Learning/class/python/day 16/Module_and_packages'

# %%
os.mkdir("test")

# %%
os.chdir("test")

# %%
os.getcwd()
# Out:
# '/Users/over/Documents/Code/Data Science & Machine Learning/class/python/day 16/Module_and_packages/test'

# %%
os.chdir("..")

# %%
os.getcwd()
# Out:
# '/Users/over/Documents/Code/Data Science & Machine Learning/class/python/day 16/Module_and_packages'

# %%
if os.path.exists("test"):
    pass
else:
    print("file Doesn't exist")

# %%
# Make folder without error
os.makedirs("test", exist_ok=True)

# %%
os.path.join("test", "file.txt")
# Out:
# 'test/file.txt'

# %%
os.listdir()
# Out:
# ['test', '01_DateTime.ipynb', '02_OSmodule.ipynb']

# %%
os.rmdir("test")

# %%
os.remove("test.txt")

# %% [markdown]
# ## Working with Environment Variables
#
# The `os` module provides functions for working with environment variables.
#
# Here are some of the most commonly used functions:
#
# - `os.getenv('var_name')`: Get the value of an Environment Variable.
# - `os.environ['var_name'] = 'var_value'`: Set the Value of an Environment Variable.

# %%
os.environ
# Out:
# environ{'COMMAND_MODE': 'unix2003',
#         'HOME': '/Users/over',
#         'LANG': 'C.UTF-8',
#         'LESS': '-R',
#         'LOGNAME': 'over',
#         'LSCOLORS': 'Gxfxcxdxbxegedabagacad',
#         'LS_COLORS': 'di=1;36:ln=35:so=32:pi=33:ex=31:bd=34;46:cd=34;43:su=30;41:sg=30;46:tw=30;42:ow=30;43',
#         'MACH_PORT_RENDEZVOUS_PEER_VALDATION': '1',
#         'MallocNanoZone': '0',
#         'OLDPWD': '/',
#         'OSLogRateLimit': '64',
#         'PAGER': 'cat',
#         'PATH': '/usr/local/bin:/Users/over/Library/Python/3.14/bin:/Users/over/.local/bin:/Users/over/.codeium/windsurf/bin:/Library/Frameworks/Python.framework/Versions/3.14/bin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/pkg/env/global/bin:/Users/over/.local/bin:/Users/over/.codeium/windsurf/bin:/Library/Frameworks/Python.framework/Versions/3.14/bin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/pkg/env/global/bin',
#         'PWD': '/',
#         'SHELL': '/bin/zsh',
#         'SHLVL': '0',
#         'SSH_AUTH_SOCK': '/var/run/com.apple.launchd.W7L12S7Pzs/Listeners',
#         'TMPDIR': '/var/folders/kj/r5cyp3k934s3d_cn_67jnkp80000gn/T/',
#         'USER': 'over',
#         'VSCODE_CODE_CACHE_PATH': '/Users/over/Library/Application Support/Code/CachedData/a5b500951314efd502d07465bd138dfbd714a960',
#         'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost',
#         'VSCODE_CWD': '/',
#         'VSCODE_ESM_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess',
#         'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true',
#         'VSCODE_IPC_HOOK': '/Users/over/Library/Application Support/Code/1.13-main.sock',
#         'VSCODE_NLS_CONFIG': '{"userLocale":"en-us","osLocale":"en-np","resolvedLanguage":"en","defaultMessagesFile":"/Applications/Visual Studio Code.app/Contents/Resources/app/out/nls.messages.json","locale":"en-us","availableLanguages":{}}',
#         'VSCODE_PID': '6150',
#         'XPC_FLAGS': '0x0',
#         'XPC_SERVICE_NAME': 'application.com.microsoft.VSCode.8224691.8224697',
#         'ZSH': '/Users/over/.oh-my-zsh',
#         '_': '/Applications/Visual Studio Code.app/Contents/MacOS/Code',
#         '__CFBundleIdentifier': 'com.microsoft.VSCode',
#         '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0',
#         'ELECTRON_RUN_AS_NODE': '1',
#         'APPLICATION_INSIGHTS_NO_STATSBEAT': 'true',
#         'MXC_BIN_DIR': '/Applications/Visual Studio Code.app/Contents/Resources/app/node_modules.asar.unpacked/@microsoft/mxc-sdk/bin',
#         'COPILOT_OTEL_FILE_EXPORTER_PATH': '/dev/null',
#         'VSCODE_L10N_BUNDLE_LOCATION': '',
#         'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1',
#         'PYTHONUNBUFFERED': '1',
#         'PYTHONIOENCODING': 'utf-8',
#         'PYTHON_FROZEN_MODULES': 'on',
#         'PYDEVD_USE_FRAME_EVAL': 'NO',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'FORCE_COLOR': '1',
#         'CLICOLOR_FORCE': '1',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
os.environ["SECRETPass"] = "adgawv9vawsv87wSA57BVA)beV"

# %%
os.getenv("SECRETPass")
# Out:
# 'adgawv9vawsv87wSA57BVA)beV'

# %%
os.getenv("LANG")
# Out:
# 'C.UTF-8'
