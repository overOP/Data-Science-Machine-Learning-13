# %% [markdown]
# Text Type
# Used for manipulating words, characters, and text data.
# str: Text strings wrapped in single, double, or triple quotes (e.g., "Hello").

# %%
name = "Pradeep"
type(name)
# Out:
# str

# %%
number = "123"
type(number)
str_to_int = int(number)
print(str_to_int)
# Out:
# 123

# %%
address = str("Kathmandu, Nepal")
print(address)
# Out:
# Kathmandu, Nepal

# %% [markdown]
# String Methods

# %%
x = "   Hello, Everyone   "
y = "---Pradeep   "

# %%
x.upper()
# Out:
# '   HELLO, EVERYONE   '

# %%
x.lower()
# Out:
# '   hello, everyone   '

# %%
x.strip()
# Out:
# 'Hello, Everyone'

# %%
a = y.lstrip("-")
a
# Out:
# 'Pradeep   '

# %%
y.rsplit()
# Out:
# ['---Pradeep']

# %%
x.replace(",", ".")
# Out:
# '   Hello. Everyone   '

# %%
x.split(",")
# Out:
# ['   Hello', ' Everyone   ']

# %%
"Ram" + "Chy"
# Out:
# 'RamChy'

# %%
"-" * 10
# Out:
# '----------'

# %% [markdown]
# string indexing

# %%
addr = "West Berlin, 789"
addr[0]
# Out:
# 'W'

# %%
addr[8]
# Out:
# 'l'

# %%
len(addr)
# Out:
# 16

# %%
addr[4]
# Out:
# ' '

# %%
addr[-5]
# Out:
# ','

# %%
addr[-1]
# Out:
# '9'

# %%
addr[10]
# Out:
# 'n'

# %% [markdown]
# string slicing
# [start_index: stop_index: stop]

# %%
slic = "West Berlin, 789"

# %%
slic[2:-1:1]
# Out:
# 'st Berlin, 78'

# %%
slic[2: :1]
# Out:
# 'st Berlin, 789'

# %%
slic[:2]
# Out:
# 'We'

# %%
slic[::3]
# Out:
# 'Wtei 9'

# %%
slic[::-1]
# Out:
# '987 ,nilreB tseW'

# %%
slic.index("e")
# Out:
# 1

# %% [markdown]
# String Formatting

# %%
name = "pradeep"
age = 24

# %%
print(f"my name is {name.capitalize()} and age is {age} ")
# Out:
# my name is Pradeep and age is 24

# %%
print(t"name is {name}")
# Out:
# Template(strings=('name is ', ''), interpolations=(Interpolation('Pradeep', 'name', None, ''),))

# %%
long_string = '''
my name is pradeep and 
i am a developer
'''

# %%
print(long_string)
# Out:
# my name is pradeep and
# i am a developer
