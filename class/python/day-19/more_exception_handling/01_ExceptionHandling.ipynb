# %% [markdown]
# # Basic Exception Handling in Python
#
# In Python, you can use a `try-except` block to catch exceptions. The basic syntax is:
#
# ```python
# try:
#     # code that may raise an exception
# except ExceptionType:
#     # code to handle the exception
# ```
#
# Here, the `try` block contains the code that may raise an exception. The `except` block contains the code that handles the exception if it occurs.
#
# ### Example
#
# The following example takes input from the user and tries to convert it into an integer. If the user enters something that cannot be converted to an integer, a `ValueError` exception is raised and handled by the `except` block.
#
# ```python
# try:
#     number = int(input("Enter a number: "))
#     print(f"You entered: {number}")
# except ValueError:
#     print("Invalid input! Please enter a valid integer.")
# ```
#
# ### Try It Yourself
#
# Run the program and try giving different types of input:
#
# * Enter a valid integer, such as `10`
# * Enter a decimal number, such as `10.5`
# * Enter text, such as `hello`
# * Enter special characters, such as `@#$`
#
# Observe how the program behaves when a `ValueError` occurs.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
try:
    num = int(input("Enter a number"))
    print(6 / num)

except ValueError as e:
    # print(e)
    # print("Invalid Input")
    print(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 try:
#       2     num = int(input("Enter a number"))
#       3     print(6 / num)
#       4
# ----> 5 except ValueError as e:
#       6     # print(e)
#       7     # print("Invalid Input")
#       8     print(0)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Catching Multiple Exceptions
#
# You can catch multiple exceptions using multiple `except` blocks in a `try-except` statement.
#
# ### Syntax
#
# ```python
# try:
#     # code that may raise an exception
# except ExceptionType1:
#     # code to handle ExceptionType1
# except ExceptionType2:
#     # code to handle ExceptionType2
# ```
#
# In this example, the `try` block may raise two different types of exceptions. Each `except` block handles a specific type of exception.
#
# ### Example
#
# ```python
# try:
#     number = int(input("Enter a number: "))
#     result = 10 / number
#     print(result)
#
# except ValueError:
#     print("Please enter a valid integer.")
#
# except ZeroDivisionError:
#     print("You cannot divide by zero.")
# ```
#
# Here:
#
# * `ValueError` occurs when the user enters something that cannot be converted to an integer.
# * `ZeroDivisionError` occurs when the user enters `0`.
# * Each `except` block handles a different type of exception.

# %%
try:
    num = int(input("Enter a number"))
    print(6 / num)

except ValueError as e:
    print("Invalid Input")
    print(0)

except ZeroDivisionError as e:
    print("Cannot divide by zero")
    print(0)

except Exception as e:
    print("unknown Error", e)
    print(0)

print("End Of Program")
# Out:
# Cannot divide by zero
# 0
# End Of Program

# %% [markdown]
# In this example, the `try` block takes input from the user and performs a division operation. If the input is not an integer or division by zero is attempted, the corresponding `except` block is executed.
#
# You can also use a single `except` block to handle multiple types of exceptions:
#
# ```python
# try:
#     number = int(input("Enter a number: "))
#     result = 10 / number
#     print(result)
#
# except (ValueError, ZeroDivisionError):
#     print("Invalid input or division by zero.")
# ```
#
# Here, the same `except` block handles both `ValueError` and `ZeroDivisionError`.

# %%
value = "abc"
try:
    print(int(value))

except (ValueError, TypeError) as e:
    print(f"{value} - Cannot convert to int : ", e)
# Out:
# abc - Cannot convert to int :  invalid literal for int() with base 10: 'abc'

# %%
class InvalidAgeException(Exception):
    """ Raise whrn input age is less than 18 """
    pass

def check_customer(age:int):
    """
    Raises
    ------
    InvalidAgeException : if provided age is leass than 18 
    """
    if age >= 18:
        print("Good to go")
    else:
        raise InvalidAgeException("Must be an adult to buy liquor, age > 18")

# %%
try:
    check_customer(
        int(input("Enter Age"))
    )

except InvalidAgeException as e:
    print("Transaction cancled : Customer under 18 ")

except (ValueError, TypeError) as e:
    print("Invalide Age - Transaction Cancled")
# Out:
# Transaction cancled : Customer under 18

# %% [markdown]
# ## The `else` Block
#
# In addition to the `try` and `except` blocks, you can also include an `else` block.
#
# The `else` block is executed **only if no exception is raised** during the execution of the `try` block. It is used to perform actions that should happen only when the `try` block completes successfully.
#
# ### Syntax
#
# ```python
# try:
#     # code that may raise an exception
# except ExceptionType:
#     # code to handle the exception
# else:
#     # code to execute if no exception occurs
# ```
#
# ### Example
#
# ```python
# try:
#     number = int(input("Enter a number: "))
#     result = 10 / number
#
# except (ValueError, ZeroDivisionError):
#     print("Invalid input or division by zero.")
#
# else:
#     print(f"Result: {result}")
# ```
#
# Here:
#
# * The `try` block attempts to convert the input to an integer and perform the division.
# * The `except` block handles `ValueError` and `ZeroDivisionError`.
# * The `else` block runs **only when no exception occurs**.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here is an example of using the else block:

# %%
try:
    x = float(input("Number"))
    y = int(input("Number"))
    result = x / y

except ValueError as err:
    print("Invalid Input -", err)
    result = 1

else:
    print("Final Result" , result)
# Out:
# Final Result 1.5

# %% [markdown]
# ## The `finally` Block
#
# The `finally` block is **always executed**, regardless of whether an exception occurs or not.
#
# It is optional and comes after the `else` block, if an `else` block is present.
#
# The `finally` block is typically used to **release resources** that were acquired in the `try` block, such as closing a file or a database connection.
#
# ### Syntax
#
# ```python
# try:
#     # code that may raise an exception
# except ExceptionType:
#     # code to handle the exception
# else:
#     # code to execute if no exception occurs
# finally:
#     # code that always executes
# ```
#
# ### Example
#
# ```python
# try:
#     number = int(input("Enter a number: "))
#     result = 10 / number
#
# except (ValueError, ZeroDivisionError):
#     print("Invalid input or division by zero.")
#
# else:
#     print(f"Result: {result}")
#
# finally:
#     print("Execution completed.")
# ```
#
# Here:
#
# * The `try` block contains the code that may raise an exception.
# * The `except` block handles the exception if one occurs.
# * The `else` block executes only when no exception occurs.
# * The `finally` block **always executes**, whether an exception occurs or not.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
try:
    x = float(input("Number"))
    y = int(input("Number"))
    result = x / y

except ValueError as err:
    print("Invalid Input -", err)
    result = 1

else:
    print("Final Result" , result)

finally:
    print("End of File")
# Out:
# Final Result 1.5
# End of File

# %%
lst = ["a","b","c","d"]

def get_elements(index):
    return lst[index]

# If Error, return last element of the list

# %%
try:
    user_index = int(input("Index of list"))
    print(get_elements(user_index))
    
except IndexError:
    print("fallback to last element")
    print(get_elements(-1))
# Out:
# c

# %%
import time

def time_tak(func):
    def inner():
        start = time.time()
        result = func()
        end = time.time()

        print(f"Total time taken: {end - start} seconds")
        return result

    return inner


@time_tak
def get_time():
    time.sleep(3)


get_time()
# Out:
# Total time taken: 3.004938840866089 seconds
