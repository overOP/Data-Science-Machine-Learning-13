# %%
2 ** 2 ** 2
# Out:
# 16

# %%
2 * 2 * 2
# Out:
# 8

# %%
["pradeep"][0][-2]
# Out:
# 'e'

# %%
list_val = ['a',2]
list_val[0] = 'A'
list_val
# Out:
# ['A', 2]

# %%
0.2 + 0.2
# Out:
# 0.4

# %%
# x = 04 we can't not give the first value 0
x = 0o4
x
# Out:
# 4

# %%
myList = [2,3,1,0,5,4,2]
sorted(myList)
# Out:
# [0, 1, 2, 2, 3, 4, 5]
