# %%
myTuple = (720, 1200)
print(myTuple)
print(type(myTuple))
# Out:
# (720, 1200)
# <class 'tuple'>

# %%
slicing Tuple

# %%
longt = (2,5,7,9,"a",8)
longt[::2]
# Out:
# (2, 7, 'a')

# %%
longt[::-1]
# Out:
# (8, 'a', 9, 7, 5, 2)

# %% [markdown]
# Tuple Methods

# %%
numbers = (1, 2, 3, 2, 4, 2)

print(numbers.count(2))
# Out:
# 3

# %%
fruits = ("apple", "banana", "mango")

print(fruits.index("banana"))
# Out:
# 1

# %% [markdown]
# Tuple Operations

# %%
t = (10, 20, 30)

print(len(t))
# Out:
# 3

# %%
numbers = (10, 50, 20)

print(max(numbers))
# Out:
# 50

# %%
numbers = (10, 20, 30)

print(sum(numbers))
# Out:
# 60
