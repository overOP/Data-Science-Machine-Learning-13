# %% [markdown]
# # Python OS Module
#
# The `os` module in Python provides a way of interacting with the operating system.
#
# It provides a way to access and manipulate files and directories, start and stop processes, get information about the system, and more.
#
# ## Working with Files and Directories
#
# Let's explore the `os` module and its various functions and methods that support working with files and directories.
#
# - `os.getcwd()`: Get the current working directory.
# - `os.mkdir('path')`: Create a new directory.
# - `os.chdir('path')`: Change the current working directory.
# - `os.listdir('path')`: List the contents of a directory.
# - `os.rename('old_name', 'new_name')`: Rename a file or a directory.
# - `os.remove('file_to_delete')`: Remove a file.
# - `os.rmdir('directory_to_delete')`: Remove a directory.
# - `os.path.dirname('path')`: Returns the name of the directory containing pathname path.
# - `os.path.exists('path')`: Checks if the path already exists; if so, returns `True`.

# %%
import os

# Get the current working directory
print(os.getcwd())

# Create a new directory
os.mkdir("test_folder")

# Change the current working directory
os.chdir("test_folder")
print(os.getcwd())

# Go back to the previous directory
os.chdir("..")

# List the contents of a directory
print(os.listdir("."))

# Rename a directory
os.rename("test_folder", "renamed_folder")

# Check if a path exists
print(os.path.exists("renamed_folder"))

# Get the directory name from a path
print(os.path.dirname("/home/user/renamed_folder/file.txt"))

# Remove a directory (must be empty)
os.rmdir("renamed_folder")

# Check again after removing
print(os.path.exists("renamed_folder"))
# Out:
# /Users/over/Documents/Code/Data Science & Machine Learning/class/python/day 15/Module_and_packages
# /Users/over/Documents/Code/Data Science & Machine Learning/class/python/day 15/Module_and_packages/test_folder
# ['test_folder', 'Os_module.ipynb']
# True
# /home/user/renamed_folder
# False

# %%
# Create a file to delete
with open("sample.txt", "w") as f:
    f.write("hello")

print(os.path.exists("sample.txt"))  # True
os.remove("sample.txt")
print(os.path.exists("sample.txt"))  # False
# Out:
# True
# False
