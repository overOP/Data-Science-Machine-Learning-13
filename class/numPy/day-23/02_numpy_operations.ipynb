# %%
import numpy as np

# %% [markdown]
# 1. Elementwise Operations
# https://numpy.org/doc/2.5/reference/routines.math.html

# %%
a = np.array(
    [
        [4,6,8], 
        [1,2,4]
    ]
)
b = np.random.randint(1, 45, size = (2,3))
c = np.linspace((0,5), (60,100), num = 4, dtype=int)

# %%
a, b, c
# Out:
# (array([[4, 6, 8],
#         [1, 2, 4]]),
#  array([[35,  7,  6],
#         [22, 28, 33]]),
#  array([[  0,   5],
#         [ 20,  36],
#         [ 40,  68],
#         [ 60, 100]]))

# %% [markdown]
# # Arithmetic Operations

# %%
# a + b
np.add(a,b)
# Out:
# array([[39, 13, 14],
#        [23, 30, 37]])

# %%
# a -b 
np.subtract(a, b)
# Out:
# array([[-31,  -1,   2],
#        [-21, -26, -29]])

# %%
# a ** 2
np.pow(a, 2)
# Out:
# array([[16, 36, 64],
#        [ 1,  4, 16]])

# %%
# a % b
quo, rem = np.divmod(b,a)
rem
# Out:
# array([[3, 1, 6],
#        [0, 0, 1]])

# %% [markdown]
# # Trignometric

# %%
np.sin(a)
# Out:
# array([[-0.7568025 , -0.2794155 ,  0.98935825],
#        [ 0.84147098,  0.90929743, -0.7568025 ]])

# %%
cot = np.reciprocal(np.tan(b))
cot
# Out:
# array([[ 2.11052962e+00,  1.14751542e+00, -3.43635300e+00],
#        [ 1.12973210e+02, -3.55328645e+00, -1.32779175e-02]])

# %% [markdown]
# # Rounding operations

# %%
np.around(cot, 2)
# Out:
# array([[ 2.1100e+00,  1.1500e+00, -3.4400e+00],
#        [ 1.1297e+02, -3.5500e+00, -1.0000e-02]])

# %%
np.floor(cot)
# Out:
# array([[  2.,   1.,  -4.],
#        [112.,  -4.,  -1.]])

# %%
np.ceil(cot)
# Out:
# array([[  3.,   2.,  -3.],
#        [113.,  -3.,  -0.]])

# %% [markdown]
#  # 2. Matrix Operations

# %%
# Transpose

# b.T
bT = np.transpose(b)
bT
# Out:
# array([[35, 22],
#        [ 7, 28],
#        [ 6, 33]])

# %%
# Matrix Multiplication

# a @ bT
# np.dot(a, bT)
res = a.dot(bT)
res
# Out:
# array([[230, 520],
#        [ 73, 210]])

# %%
# Trace [Diagnoal sum]
d_sum = np.trace(res)
print(d_sum)
# Out:
# 440

# %%
# Rank
np.linalg.matrix_rank(a)
# Out:
# np.int64(2)

# %%
# Determinat
b = np.random.randint(1, 5, size = (3,3))

det_b = np.linalg.det(b)
det_b
# Out:
# np.float64(-6.0)

# %%
# Inverse
inv_b = np.linalg.inv(b)
inv_b
# Out:
# array([[ 1.16666667, -0.5       , -0.5       ],
#        [ 1.33333333, -1.        ,  0.        ],
#        [-2.16666667,  1.5       ,  0.5       ]])

# %% [markdown]
# Solve Equation : 4x + 2y = 8 , 5x + 3y = 9

# %%
A = np.array([[4,2] ,[5,3]])
B = np.array([8,9])

# %%
A_inv = np.linalg.inv(A)

# %%
X = np.dot(A_inv, B)

# %%
X
# Out:
# array([ 3., -2.])

# %%
# Array Broadcasting
A
# Out:
# array([[4, 2],
#        [5, 3]])

# %%
B
# Out:
# array([8, 9])

# %%
A + B
# Out:
# array([[12, 11],
#        [13, 12]])
