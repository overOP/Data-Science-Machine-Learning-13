# %%
import numpy as np

# %%
import pandas as pd

data = pd.read_csv("../data/DNA_Dataset_Normalized.csv", index_col = 0)

data.head()
# Out:
#           gene_0    gene_1    gene_2    gene_3     gene_4  gene_5    gene_6  \
# sample_0     0.0  2.017209  3.265527  5.478487  10.431999     0.0  7.175175
# sample_1     0.0  0.592732  1.588421  7.586157   9.623011     0.0  6.816049
# sample_2     0.0  3.511759  4.327199  6.881787   9.870730     0.0  6.972130
# sample_3     0.0  3.663618  4.507649  6.659068  10.196184     0.0  7.843375
# sample_4     0.0  2.655741  2.821547  6.539454   9.738265     0.0  6.566967
#
#             gene_7  gene_8  gene_9  ...  gene_20521  gene_20522  gene_20523  \
# sample_0  0.591871     0.0     0.0  ...    4.926711    8.210257    9.723516
# sample_1  0.000000     0.0     0.0  ...    4.593372    7.323865    9.740931
# sample_2  0.452595     0.0     0.0  ...    5.125213    8.127123   10.908640
# sample_3  0.434882     0.0     0.0  ...    6.076566    8.792959   10.141520
# sample_4  0.360982     0.0     0.0  ...    5.996032    8.891425   10.373790
#
# ...

# %%
X = data.to_numpy()

# %%
X.shape
# Out:
# (801, 20531)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=500)

# %%
X_reduced = pca.fit_transform(X)

# %%
X_reduced.shape
# Out:
# (801, 500)

# %%
sum(pca.explained_variance_ratio_)
# Out:
# np.float64(0.9538880595158485)

# %%
X_reduced
# Out:
# array([[-62.75541522,  94.07197346, -89.51983114, ...,   1.62518918,
#          -3.23295928,  -2.42485572],
#        [ -2.43289636, -90.58584184,   1.06730787, ...,   0.9146073 ,
#          -0.83184481,  -2.66166753],
#        [-71.26685285,   8.06460774, -66.11245485, ...,   1.63749969,
#          -1.1051887 ,  -3.55747048],
#        ...,
#        [ 10.48626145, -21.57059456, -41.34587844, ...,   1.12354493,
#           0.90453763,   1.42083108],
#        [-55.06360486,  92.39477804, -80.05003937, ...,   1.87442974,
#          -7.93967383,  -1.26822797],
#        [-49.10303379,  50.99763908, -40.50375438, ...,  -2.57940575,
#          -0.0978211 ,   7.16456354]], shape=(801, 500))
