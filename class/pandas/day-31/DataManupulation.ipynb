# %%
import pandas as pd

# Target Survived 
df = pd.read_csv("../data/titanic_data.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Inserting and Deleting Columns and Rows

# %%
# Dropping a column
# dataframe.drop(<column_name>, axis)

df.drop("PassengerId", axis = 1, inplace= True)
# df.drop(["PassengerId", "Name"], axis = 1, inplace= True)

# df.drop(columns="PassengerId", inplace= False)
# df.drop(columns=["PassengerId", "Name"], inplace= False)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
# Dropping a row
# dataframe.drop(<row_index>, axis)

# df.drop([2,4], axis = 0, inplace= False)
df.drop(index=[2,4], inplace= False).head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C
# 3  female  35.0      1      0     113803  53.1000  C123        S
# 5    male   NaN      0      0     330877   8.4583   NaN        Q
# 6    male  54.0      0      0      17463  51.8625   E46        S

# %%
# Inserting or Replacing a columns

# Getting List of Initials
initials = [name.split(",")[-1].split(".")[0].strip() for name in df.Name]

# %%
df["initials"] = initials

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   initials
# 0       Mr
# 1      Mrs
# 2     Miss
# 3      Mrs
# 4       Mr

# %%
# Alternative to insert
# df.insert(loc = 3, column="new_initials", value=initials)

# df.head()

# %%
# Insering or replacing Rows

df.loc[900,:] = [0, 3, "Braund, Mr. Owen Harris", "male", 22.0, 1, 0, "A/5 21171",7.2500 ,pd.NA, "S","Mr"]

df.tail()
# Out:
#      Survived  Pclass                                      Name     Sex   Age  \
# 887       1.0     1.0              Graham, Miss. Margaret Edith  female  19.0
# 888       0.0     3.0  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1.0     1.0                     Behr, Mr. Karl Howell    male  26.0
# 890       0.0     3.0                       Dooley, Mr. Patrick    male  32.0
# 900       0.0     3.0                   Braund, Mr. Owen Harris    male  22.0
#
#      SibSp  Parch      Ticket   Fare Cabin Embarked initials
# 887    0.0    0.0      112053  30.00   B42        S     Miss
# 888    1.0    2.0  W./C. 6607  23.45   NaN        S     Miss
# 889    0.0    0.0      111369  30.00  C148        C       Mr
# 890    0.0    0.0      370376   7.75   NaN        Q       Mr
# 900    1.0    0.0   A/5 21171   7.25   NaN        S       Mr

# %% [markdown]
# ## Handling Null or NaN or NA values

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       688
# Embarked      2
# initials      0
# dtype: int64

# %% [markdown]
# 1. Removing Null Values
# 2. Fill something (Imputation)
# 3. Null as new feature ( Feature Engineering)
#
# **0 -> column wise -> vertical**
#
# **1 -> row wise -> horizontal**

# %%
# Removing Null Values
df.dropna(subset="Embarked", axis = 0, ignore_index=True, inplace=True)

# %%
df.shape
# Out:
# (890, 12)

# %%
# Null value as feature
df.Cabin = df.Cabin.notna().astype(int)

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin         0
# Embarked      0
# initials      0
# dtype: int64

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0       0.0     3.0                            Braund, Mr. Owen Harris
# 1       1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       1.0     3.0                             Heikkinen, Miss. Laina
# 3       1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       0.0     3.0                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare  Cabin Embarked  \
# 0    male  22.0    1.0    0.0         A/5 21171   7.2500      0        S
# 1  female  38.0    1.0    0.0          PC 17599  71.2833      1        C
# 2  female  26.0    0.0    0.0  STON/O2. 3101282   7.9250      0        S
# 3  female  35.0    1.0    0.0            113803  53.1000      1        S
# 4    male  35.0    0.0    0.0            373450   8.0500      0        S
#
#   initials
# 0       Mr
# 1      Mrs
# 2     Miss
# 3      Mrs
# 4       Mr

# %%
# Fill Null Values

age_median = df.Age.median()
age_median
# Out:
# np.float64(28.0)

# %%
df.Age.plot(kind = "hist", bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_fillAge = df.copy()

df_fillAge.loc[:,"Age"] = df_fillAge.Age.fillna(value= age_median, inplace=False)

# %%
df_fillAge.isna().sum(axis = 0)
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# initials    0
# dtype: int64

# %%
df_fillAge.Age.describe()
# Out:
# count    890.000000
# mean      29.306933
# std       12.979943
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df_fillAge.Age.plot(kind = "hist", bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Inputation of Age wrt Gender
group_by_sex = df.groupby(by = "Sex")

# %%
median_ages = group_by_sex["Age"].transform("median")

# %%
df_fillAge_with_sex = df.copy()

df_fillAge_with_sex.loc[:,"Age"] = df_fillAge_with_sex.Age.fillna(
    value= median_ages
)

# %%
df_fillAge_with_sex.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# initials    0
# dtype: int64

# %%
df_fillAge_with_sex.Age.plot(kind = "hist", bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.initials.value_counts()
# Out:
# initials
# Mr              518
# Miss            181
# Mrs             124
# Master           40
# Dr                7
# Rev               6
# Major             2
# Mlle              2
# Col               2
# Don               1
# Mme               1
# Ms                1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %% [markdown]
# ### Handling Null value for Age, using initials groups.

# %%
group_by_initials = df.groupby(by = "initials")

# %%
meadin_ages = group_by_initials["Age"].transform("median")

# %%
df_fillAge_with_initial = df.copy()

df_fillAge_with_initial.Age = df_fillAge_with_initial.Age.fillna(
    value= meadin_ages
)

# %%
df_fillAge_with_initial.Age.plot(kind = "hist", bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Handling Null value for Age, using initials (Mr., Mrs,  Miss or Master)groups.

# %%
df.initials = df.initials.replace(
    to_replace=["Rev", "Major", "Col", "Don", "Sir", "Capt", "Jonkheer"], 
    value="Mr",
)

# %%
df.initials = df.initials.replace(
    to_replace= {"Mlle" : "Miss", "Mme" : "Mrs","Ms" : "Mrs","Lady" : "Mrs","the Countess" : "Mrs"}
)

# %%
def relace_with_gender(row):
    value = "Mr" if row.Sex == "male" else "Mrs"
    return row.initials.replace("Dr", value, True)

# %%
df.initials = df.apply(relace_with_gender, axis=1)

# %%
df.initials.value_counts()
# Out:
# initials
# Mr        538
# Miss      183
# Mrs       129
# Master     40
# Name: count, dtype: int64

# %% [markdown]
# ---

# %%
# Exercise

def get_initals(name):
    first_name = name.split(",")[-1]
    title = first_name.split(".")[0]
    return title.strip().lower()

initials = df.Name.apply(get_initals)
print(initials)
# Out:
# 0        mr
# 1       mrs
# 2      miss
# 3       mrs
# 4        mr
#        ...
# 885    miss
# 886    miss
# 887      mr
# 888      mr
# 889      mr
# Name: Name, Length: 890, dtype: str

# %%
# Aggregatee
df.Age.aggregate(["mean", "median"])
# Out:
# mean      29.631374
# median    28.000000
# Name: Age, dtype: float64

# %% [markdown]
# ---

# %%
group_by_initials = df.groupby(by = "initials")

# %%
meadin_ages = group_by_initials["Age"].transform("median")

# %%
df_fillAge_with_initial = df.copy()

df_fillAge_with_initial.Age = df_fillAge_with_initial.Age.fillna(
    value= meadin_ages
)

# %%
df_fillAge_with_initial.Age.plot(kind = "hist", bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_fillAge_with_initial.Age.describe()
# Out:
# count    890.000000
# mean      29.317045
# std       13.214172
# min        0.420000
# 25%       21.000000
# 50%       30.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df_fillAge_with_initial.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# initials    0
# dtype: int64

# %% [markdown]
# ### Cleaning Duplicates

# %%
df_fillAge_with_initial[df_fillAge_with_initial.duplicated()]
# Out:
#      Survived  Pclass                     Name   Sex   Age  SibSp  Parch  \
# 889       0.0     3.0  Braund, Mr. Owen Harris  male  22.0    1.0    0.0
#
#         Ticket  Fare  Cabin Embarked initials
# 889  A/5 21171  7.25      0        S       Mr

# %%
df_fillAge_with_initial.drop_duplicates(inplace=True)

# %%
# df_fillAge_with_initial.duplicated(subset=["Age", "Fare"])

# %% [markdown]
# ## Data Management
#
# **Type Conversion**
#
# dataframe.astype()

# %%
df.dtypes
# Out:
# Survived    float64
# Pclass      float64
# Name            str
# Sex             str
# Age         float64
# SibSp       float64
# Parch       float64
# Ticket          str
# Fare        float64
# Cabin         int64
# Embarked        str
# initials        str
# dtype: object

# %%
df.Cabin = df.Cabin.astype(float)

# %%
df = df.astype({
    "Survived" : bool, "Pclass" : "int16"
})

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0     False       3                            Braund, Mr. Owen Harris
# 1      True       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      True       3                             Heikkinen, Miss. Laina
# 3      True       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4     False       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare  Cabin Embarked  \
# 0    male  22.0    1.0    0.0         A/5 21171   7.2500    0.0        S
# 1  female  38.0    1.0    0.0          PC 17599  71.2833    1.0        C
# 2  female  26.0    0.0    0.0  STON/O2. 3101282   7.9250    0.0        S
# 3  female  35.0    1.0    0.0            113803  53.1000    1.0        S
# 4    male  35.0    0.0    0.0            373450   8.0500    0.0        S
#
#   initials
# 0       Mr
# 1      Mrs
# 2     Miss
# 3      Mrs
# 4       Mr

# %% [markdown]
# **Indexing**
#
# get index -> dataframe.index
#
# set index -> dataframe.index = Sequence or Series
#
# reset index -> datafraem.reset_index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=890, step=1)

# %%
df.set_index("Name", drop = True)
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                False       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      True       1  female
# Heikkinen, Miss. Laina                                  True       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            True       1  female
# Allen, Mr. William Henry                               False       3    male
# ...                                                      ...     ...     ...
# Graham, Miss. Margaret Edith                            True       1  female
# Johnston, Miss. Catherine Helen "Carrie"               False       3  female
# Behr, Mr. Karl Howell                                   True       1    male
# Dooley, Mr. Patrick                                    False       3    male
# Braund, Mr. Owen Harris                                False       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0    1.0    0.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0    1.0    0.0
# Heikkinen, Miss. Laina                              26.0    0.0    0.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0    1.0    0.0
# Allen, Mr. William Henry                            35.0    0.0    0.0
# ...                                                  ...    ...    ...
# Graham, Miss. Margaret Edith                        19.0    0.0    0.0
# Johnston, Miss. Catherine Helen "Carrie"             NaN    1.0    2.0
# Behr, Mr. Karl Howell                               26.0    0.0    0.0
# Dooley, Mr. Patrick                                 32.0    0.0    0.0
# Braund, Mr. Owen Harris                             22.0    1.0    0.0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
# ...                                                              ...      ...
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
#
#                                                     Cabin Embarked initials
# Name
# Braund, Mr. Owen Harris                               0.0        S       Mr
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    1.0        C      Mrs
# Heikkinen, Miss. Laina                                0.0        S     Miss
# Futrelle, Mrs. Jacques Heath (Lily May Peel)          1.0        S      Mrs
# Allen, Mr. William Henry                              0.0        S       Mr
# ...                                                   ...      ...      ...
# Graham, Miss. Margaret Edith                          1.0        S     Miss
# Johnston, Miss. Catherine Helen "Carrie"              0.0        S     Miss
# Behr, Mr. Karl Howell                                 1.0        C       Mr
# Dooley, Mr. Patrick                                   0.0        Q       Mr
# Braund, Mr. Owen Harris                               0.0        S       Mr
#
# [890 rows x 11 columns]

# %%
df.reset_index(drop = True)
# Out:
#      Survived  Pclass                                               Name  \
# 0       False       3                            Braund, Mr. Owen Harris
# 1        True       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2        True       3                             Heikkinen, Miss. Laina
# 3        True       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       False       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 885      True       1                       Graham, Miss. Margaret Edith
# 886     False       3           Johnston, Miss. Catherine Helen "Carrie"
# 887      True       1                              Behr, Mr. Karl Howell
# 888     False       3                                Dooley, Mr. Patrick
# 889     False       3                            Braund, Mr. Owen Harris
#
#         Sex   Age  SibSp  Parch            Ticket     Fare  Cabin Embarked  \
# 0      male  22.0    1.0    0.0         A/5 21171   7.2500    0.0        S
# 1    female  38.0    1.0    0.0          PC 17599  71.2833    1.0        C
# 2    female  26.0    0.0    0.0  STON/O2. 3101282   7.9250    0.0        S
# 3    female  35.0    1.0    0.0            113803  53.1000    1.0        S
# 4      male  35.0    0.0    0.0            373450   8.0500    0.0        S
# ..      ...   ...    ...    ...               ...      ...    ...      ...
# 885  female  19.0    0.0    0.0            112053  30.0000    1.0        S
# 886  female   NaN    1.0    2.0        W./C. 6607  23.4500    0.0        S
# 887    male  26.0    0.0    0.0            111369  30.0000    1.0        C
# 888    male  32.0    0.0    0.0            370376   7.7500    0.0        Q
# 889    male  22.0    1.0    0.0         A/5 21171   7.2500    0.0        S
#
#     initials
# 0         Mr
# 1        Mrs
# 2       Miss
# 3        Mrs
# 4         Mr
# ..       ...
# 885     Miss
# 886     Miss
# 887       Mr
# 888       Mr
# 889       Mr
#
# [890 rows x 12 columns]
