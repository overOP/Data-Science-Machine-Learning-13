# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
x = np.random.standard_t(500,size=1000)
x[:15]
# Out:
# array([-0.18374688, -0.30125276,  1.9994868 ,  0.03308183,  0.93187682,
#        -0.14063714, -1.56171917, -1.11484602,  1.40550333,  0.88837379,
#        -0.8046303 ,  0.13330472,  0.53853901,  0.28465167, -1.07104064])

# %% [markdown]
# ## Measure of Central Tendency
#
# Measures of central tendency are statistical measures that provide information about the central or typical value of a dataset. They give us a sense of where the data is centered or concentrated. The three common measures of central tendency are:
#
# - Mean
# - Median
# - Mode
#
# ## Mean
#
# The mean, denoted by $\bar{x}$, is a measure of central tendency that represents the average value of a dataset. It is calculated by summing all the values in the dataset and dividing by the number of observations.
#
# ### Formula
#
# $$
# \bar{x} = \frac{\sum_{i=1}^{n} x_i}{n}
# $$
#
# Where:
#
# - $\bar{x}$ = Mean
# - $x_i$ = Each value in the dataset
# - $n$ = Total number of observations
# - $\sum$ = Sum of all values

# %%
_mean = np.mean(x)
print(f"Mean of x : {_mean}")
# Out:
# Mean of x : 0.029837079920026224

# %%
plt.hist(x,bins =20, color='blue')
plt.axvline(x = _mean, color = 'yellow')

# %% [markdown]
# ### Median
#
# The median is another measure of central tendency that represents the middle value of a sorted dataset. If the dataset has an odd number of observations, the median is the middle value. If the dataset has an even number of observations, the median is the average of the two middle values.
#
# We can calculate the median values in two different ways:
#
# #### Odd Number of Observations:
#
# If the dataset has an odd number of observations $(n)$, the median is the middle value when the dataset is arranged in ascending order.
#
# The formula for calculating the median in this case is:
#
# $$
# \text{Median} = x_{\frac{n+1}{2}}
# $$
#
# #### Even Number of Observations:
#
# If the dataset has an even number of observations $(n)$, the median is the average of the two middle values when the dataset is arranged in ascending order.
#
# The formula for calculating the median in this case is:
#
# $$
# \text{Median} = \frac{x_{\frac{n}{2}} + x_{\frac{n}{2}+1}}{2}
# $$

# %%
_median = np.median(x)
print(f"Mean of x : {_median}")
# Out:
# Mean of x : -0.009414474193747729

# %%
plt.hist(x,bins =20, color='blue')
plt.axvline(x = _mean, color = 'yellow')
plt.axvline(x = _median, color = 'red')

# %% [markdown]
# ### Mode
#
# The mode is a measure of central tendency that represents the most frequently occurring value(s) in a dataset. A dataset can have one mode (unimodal) or multiple modes (multimodal).
#
# Mostly used with categorical data.

# %%
_mode = stats.mode(x).mode
print("Mode: ", _mode)
# Out:
# Mode:  -3.167026493293157

# %%
plt.hist(x, color='blue')
plt.axvline(x = _mean, color = 'yellow')
plt.axvline(x = _median, color = 'red')
plt.axvline(x = _mode, color = 'green')
