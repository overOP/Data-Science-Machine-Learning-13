# %% [markdown]
# ## Merging
#
# Merging is the process of combining two or more dataframes based on common columns. This technique is used when the datasets have some common columns. You can use the `pd.merge()` function from the `pandas` library to merge dataframes.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['Ram', 'Shyam', 'Hari', 'Krishna'],
    'age': [21, 65, 34, 88]
})

df2 = pd.DataFrame({
    "id" : [1, 2, 3, 5], 
    "principle": [500, 658, 4032, 500], 
    "interest" : [6.3, 4.25, 9.8, 5.6]
})

# %%
df1
# Out:
#    id     name  age
# 0   1      Ram   21
# 1   2    Shyam   65
# 2   3     Hari   34
# 3   4  Krishna   88

# %%
df2
# Out:
#    id  principle  interest
# 0   1        500      6.30
# 1   2        658      4.25
# 2   3       4032      9.80
# 3   5        500      5.60

# %%
# Basic

students = pd.DataFrame({
    "Student_ID": [1, 2, 3, 4],
    "Name": ["Alice", "Bob", "Charlie", "David"]
})

marks = pd.DataFrame({
    "Student_ID": [1, 2, 3, 4],
    "Marks": [85, 62, 91, 74]
})

pd.merge(
    students,
    marks,
    on="Student_ID"
)
# Out:
#    Student_ID     Name  Marks
# 0           1    Alice     85
# 1           2      Bob     62
# 2           3  Charlie     91
# 3           4    David     74

# %%
# merge() with Missing IDs

students = pd.DataFrame({
    "Student_ID": [1, 2, 3, 4],
    "Name": ["Alice", "Bob", "Charlie", "David"]
})

marks = pd.DataFrame({
    "Student_ID": [1, 2, 3, 5],
    "Marks": [85, 62, 91, 78]
})

pd.merge(
    students,
    marks,
    on="Student_ID",
    how="inner"
)
# Out:
#    Student_ID     Name  Marks
# 0           1    Alice     85
# 1           2      Bob     62
# 2           3  Charlie     91

# %%
# how="left"

students = pd.DataFrame({
    "Student_ID": [1, 2, 3, 4],
    "Name": ["Alice", "Bob", "Charlie", "David"]
})

marks = pd.DataFrame({
    "Student_ID": [1, 2, 3, 5],
    "Marks": [85, 62, 91, 78]
})

pd.merge(
    students,
    marks,
    on="Student_ID",
    how="left"
)
# Out:
#    Student_ID     Name  Marks
# 0           1    Alice   85.0
# 1           2      Bob   62.0
# 2           3  Charlie   91.0
# 3           4    David    NaN

# %%
# how="right"

students = pd.DataFrame({
    "Student_ID": [1, 2, 3, 4],
    "Name": ["Alice", "Bob", "Charlie", "David"]
})

marks = pd.DataFrame({
    "Student_ID": [1, 2, 3, 5],
    "Marks": [85, 62, 91, 78]
})

pd.merge(
    students,
    marks,
    on="Student_ID",
    how="right"
)
# Out:
#    Student_ID     Name  Marks
# 0           1    Alice     85
# 1           2      Bob     62
# 2           3  Charlie     91
# 3           5      NaN     78

# %%
# how="outer"

students = pd.DataFrame({
    "Student_ID": [1, 2, 3, 4],
    "Name": ["Alice", "Bob", "Charlie", "David"]
})

marks = pd.DataFrame({
    "Student_ID": [1, 2, 3, 5],
    "Marks": [85, 62, 91, 78]
})

pd.merge(
    students,
    marks,
    on="Student_ID",
    how="outer"
)
# Out:
#    Student_ID     Name  Marks
# 0           1    Alice   85.0
# 1           2      Bob   62.0
# 2           3  Charlie   91.0
# 3           4    David    NaN
# 4           5      NaN   78.0

# %%
# Merge Using Different Column Names

students = pd.DataFrame({
    "Student_ID": [1, 2, 3, 4],
    "Name": ["Alice", "Bob", "Charlie", "David"]
})

marks = pd.DataFrame({
    "ID": [1, 2, 3, 4],
    "Marks": [85, 62, 91, 74]
})

pd.merge(
    students,
    marks,
    left_on="Student_ID",
    right_on="ID"
)
# Out:
#    Student_ID     Name  ID  Marks
# 0           1    Alice   1     85
# 1           2      Bob   2     62
# 2           3  Charlie   3     91
# 3           4    David   4     74

# %%
# Merge Using Multiple Columns

students = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "City": ["Kathmandu", "Pokhara", "Kathmandu", "Pokhara"],
    "Age": [20, 21, 19, 22]
})

marks = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "City": ["Kathmandu", "Pokhara", "Kathmandu", "Pokhara"],
    "Marks": [85, 62, 91, 74]
})

pd.merge(
    students,
    marks,
    on=["Name", "City"]
)
# Out:
#       Name       City  Age  Marks
# 0    Alice  Kathmandu   20     85
# 1      Bob    Pokhara   21     62
# 2  Charlie  Kathmandu   19     91
# 3    David    Pokhara   22     74

# %%
# Merge + how="left" with Multiple Columns

students = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "City": ["Kathmandu", "Pokhara", "Kathmandu", "Pokhara"],
    "Age": [20, 21, 19, 22]
})

marks = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie"],
    "City": ["Kathmandu", "Pokhara", "Kathmandu"],
    "Marks": [85, 62, 91]
})

pd.merge(
    students,
    marks,
    on=["Name", "City"],
    how="left"
)
# Out:
#       Name       City  Age  Marks
# 0    Alice  Kathmandu   20   85.0
# 1      Bob    Pokhara   21   62.0
# 2  Charlie  Kathmandu   19   91.0
# 3    David    Pokhara   22    NaN
